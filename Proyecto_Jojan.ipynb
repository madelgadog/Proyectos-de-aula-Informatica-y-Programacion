# %% [markdown]
# <a href="https://colab.research.google.com/github/madelgadog/Proyectos-de-aula-Informatica-y-Programacion/blob/main/Proyecto_Jojan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://colab.research.google.com/drive/1DWFuF2P3wmNeOndbzLLuiJvmDntP_yOp?usp=sharing
import scipy.optimize as opt
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
n = input ("ingresa tu nombre  ")
print ("hola futuro quimico", n)
b = int(input ("ingresa el valor a analizar "))
while b != (1):
 if b % 2 == 0:
    print('El número es', b)
    b= int(b/2)
 else:
    print('El número es', b)
    b = int(b*3) + 1
x = np.array(range (b))
y=np.zeros(len(x))
# Out:
# ingresa tu nombre  Miguel
# hola futuro quimico Miguel
# ingresa el valor a analizar 6887957687983544234567893
# El número es 6887957687983544234567893
# El número es 20663873063950632703703680
# El número es 10331936531975316470497280
# El número es 5165968265987658235248640
# El número es 2582984132993829117624320
# El número es 1291492066496914558812160
# El número es 645746033248457279406080
# El número es 322873016624228639703040
# El número es 161436508312114319851520
# El número es 80718254156057159925760
# El número es 40359127078028579962880
# El número es 20179563539014289981440
# El número es 10089781769507144990720
# El número es 5044890884753572495360
# El número es 2522445442376786247680
# El número es 1261222721188393123840
# El número es 630611360594196561920
# El número es 315305680297098280960
# El número es 157652840148549140480
# El número es 78826420074274570240
# El número es 39413210037137285120
# El número es 19706605018568642560
# ...
