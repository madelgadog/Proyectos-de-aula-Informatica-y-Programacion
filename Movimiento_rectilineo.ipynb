# %% [markdown]
# <a href="https://colab.research.google.com/github/madelgadog/Proyectos-de-aula-Informatica-y-Programacion/blob/main/Movimiento_rectilineo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

while True:
    print("""
    Dime, ¿qué movimiento vamos a estudiar?
    
    1) Movimiento rectilineo uniforme (MRU)
    2) Movimiento rectilineo uniformemente variado (MRUV) 
    3) Compocision de movimientos en el plano
    4) Apagar calculadora
    """)
    opcion = int(input("Elige una opción: ") )     

    if opcion == 1:
        print(" ")
        print("""
    Dime, ¿qué valor vamos a hallar?
    
    1) La velocidad
    2) La distancia inicial 
    3) La distancia final
    4) el tiempo
    """)
        opcion2 = int(input("Elige una opción: ") )
        if opcion2 == 1:
           print(" ")
           Di = float(input("Introduce la distancia inicial en metros: ") )
           Df = float(input("Introduce la distancia final en metros: ") )
           t = float(input("Introduce la tiempo en segundos: ") )
           print ("El valor de la velocidad es: ",(Df-Di)/t,"en metros sobre segundos")
        elif opcion2 == 2:
           print(" ")
           Df = float(input("Introduce la distancia final en metros: ") )
           t = float(input("Introduce la tiempo en segundos: ") )
           V =float(input("Introduce la velocidad en metros sobre segundos: ") )
           print("El valor de la distacia inicial es ",(V*t)+Df," en metros")
        elif opcion2 == 3:
           Di = float(input("Introduce la distancia inicial en metros: ") )
           t = float(input("Introduce la tiempo en segundos: ") )
           V =float(input("Introduce la velocidad en metros sobre segundos: ") )
           print("El valor de la distacia final es ",(V*t)+Di)
        elif opcion2 == 4:
           Di = float(input("Introduce la distancia inicial en metros: ") )
           Df = float(input("Introduce la distancia final en metros: ") )
           V =float(input("Introduce la velocidad en metros sobre segundos: ") )
           print ("El valor del tiempo es: ",(Df-Di)/V)
    if opcion == 2:
        print(" ")
        print("""
    Dime, ¿qué valor vamos a hallar?
    
    1) La velocidad inicial
    2) La distancia recorrida
    3) La velocidad final (sabiendo el tiempo)
    4) La velocidad final (sabiendo la distancia)
    5) el tiempo
    6) La aceleración
    """)
        opcion3 = int(input("Elige una opción: ") )
        if opcion3 == 1:
           print(" ")
           Vf = float(input("Introduce la velocidad final en metros: ") )
           t = float(input("Introduce la tiempo en segundos: ") )
           a = float(input("Indtroduce la aceleracion en metro sobre segundo:: "))
           print("El valor de la velocidad inicial es: ",-1*(a*t)/Vf)
        elif opcion3 == 2:
           print(" ")
           t = float(input("Introduce la tiempo en segundos: ") )
           a = float(input("Indtroduce la aceleracion en metro sobre segundo: "))
           Vi = float(input("Introduce la velocidad inicial en metros"))
           ele = t*t
           print("El valor de la distacia recorrida es ",(Vi*t)+((a*ele)/2))
        elif opcion3 == 3:
           a = float(input("Introduce la aceleracion en metro sobre segundo: ") )
           t = float(input("Introduce la tiempo en segundos: ") )
           Vi =float(input("Introduce la velocidad en metros sobre segundos: ") )
           print("El valor de la velocidad final (sabiendo el tiempo) es ",Vi+(a*t))
        elif opcion3 == 4:
           a = float(input("Introduce la aceleracion en metro sobre segundo: ") )
           D = float(input("Introduce la distancia recorrida en metros: ") )
           Vi =float(input("Introduce la velocidad en metros sobre segundos: ") )
           x=Vi**2+2*(a*D) 
           R = math.sqrt(x)
           print("El valor de la velocidad final (sabiendo la distancia ) es ",R)
        elif opcion3 == 5:
           Vi =float(input("Introduce la velocidad en metros sobre segundos: ") )
           Vf = float(input("Introduce la velocidad final en metros: ")  )
           a = float(input("Introduce la aceleracion en metro sobre segundo: ") )
           print ("El valor del tiempo es: ",(Vf-Vi)/a)
        elif opcion3 == 6:
           Vi =float(input("Introduce la velocidad en metros sobre segundos: ") )
           Vf = float(input("Introduce la velocidad final en metros: ")  )
           t = float(input("Introduce la tiempo en segundos: ") )
           print ("El valor de la aceleracion es: ",(Vf-Vi)/t)
    elif opcion == 3:
        print(" ")
        print("""
    Dime, ¿qué composicion de movimientos vamos a estudiar?
    
    1) Movimientos rectilineos uniformes paralelos en el mismo sentido
    2) Movimientos rectilineos uniformes paralelos en sentido contrario
    3) Movimientos rectilineos uniformes perpendiculares
    4) Tiro horizontal
    """)
        opcion4 = int(input("Elige una opción: ") )
        if opcion4 == 1:
          print(" ")
          print("""
    Dime, ¿qué valor vamos a hallar?
    
    1) La velocidad inicial
    2) La Velocidad final
    3) La velocidad total
    """)
          opcion5 = int(input("Elige una opción: ") )
          if opcion5 == 1:
             print(" ")
             Vf = float(input("Introduce la velocidad final en metros: ") )
             Vt = float(input("Introduce la velocidad total en metros: ") )
             print("El valor de la velocidad inicial es: ",Vf-Vt)
          elif opcion5 == 2:
             print(" ")
             Vt = float(input("Introduce la velocidad total en metros: ") )
             Vi = float(input("Introduce la velocidad inicial en metros: ") )
             print("El valor de la velocidad final es: ",Vt-Vi)
          elif opcion5 == 3:
             Vf = float(input("Introduce la velocidad final en metros: ") )
             Vi = float(input("Introduce la velocidad inicial en metros: ") )
             print("El valor de la velocidad total es: ",Vf+Vi)
        if opcion4 == 2:
          print(" ")
          print("""
    Dime, ¿qué valor vamos a hallar?
    
    1) La velocidad inicial
    2) La Velocidad final
    3) La velocidad total
    """)
          opcion5 = int(input("Elige una opción: ") )
          if opcion5 == 1:
             print(" ")
             Vf = float(input("Introduce la velocidad final en metros: ") )
             Vt = float(input("Introduce la velocidad total en metros: ") )
             print("El valor de la velocidad inicial es: ",Vf+Vt)
          elif opcion5 == 2:
             print(" ")
             Vt = float(input("Introduce la velocidad total en metros: ") )
             Vi = float(input("Introduce la velocidad inicial en metros: ") )
             print("El valor de la velocidad final es: ",Vt+Vi)
          elif opcion5 == 3:
             Vf = float(input("Introduce la velocidad final en metros: ") )
             Vi = float(input("Introduce la velocidad inicial en metros: ") )
             print("El valor de la velocidad total es: ",Vf-Vi)
        if opcion4 == 3:
          print(" ")
          print("""
    Dime, ¿qué valor vamos a hallar?
    
    1) La velocidad en el eje X
    2) La Velocidad en el eje Y
    3) La velocidad resultante
    4) El tiempo (sabiendo los datos de Y)
    5) El tiempo (sabiendo los datos de X)
    6) Distancia en Y
    7) Distancia en X
    8) Distancia total
    """)
          opcion5 = int(input("Elige una opción: ") )
          if opcion5 == 1:
             print(" ")
             X = float(input("Introduce la la distancia en el eje X en metros: ") )
             t = float(input("Introduce el tiempo en segundos: ") )
             print("El valor de la velocidad en el eje X es: ",X/t)
          elif opcion5 == 2:
             print(" ")
             Y = float(input("Introduce la velocidad en el eje Y en metros: ") )
             t = float(input("Introduce el tiempo en segundos: ") )
             print("El valor de la velocidad en el eje Y es: ",Y/t)
          elif opcion5 == 3:
             Vy = float(input("Introduce la velocidad en el eje Y en metros sobre segundos: ") )
             Vx = float(input("Introduce la velocidad en el eje X en metros sobre segundos: ") )
             Y2 = Vy*Vy
             X2 = Vx*Vx
             R = Y2+X2
             print("El valor de la velocidad total es: ",math.sqrt(R))
          elif opcion5 == 4:
             Vy = float(input("Introduce la velocidad en el eje Y en metros sobre segundos: ") )
             Y = float(input("Introduce el valor de la distancia en Y en metros: ") )
             print("El valor del tiempo en segundos es: ",Y/Vy)
          elif opcion5 == 5:
             Vx = float(input("Introduce la velocidad en el eje X en metros sobre segundos: ") )
             X = float(input("Introduce el valor de la distancia en X en metros: ") )
             print("El valor de la velocidad total es: ",X/Vx)
          elif opcion5 == 6:
             Vy = float(input("Introduce la velocidad en el eje Y en metros sobre segundos: ") )
             t = float(input("Introduce el tiempo en segundos"))
             print("El valor de la distancia en Y total es: ",Vy*t)
          elif opcion5 == 7:
             Vx = float(input("Introduce la velocidad en el eje X en metros sobre segundos: ") )
             t = float(input("Introduce el tiempo en segundos")) 
             print("El valor de la distancia en X total es: ",Vx*t)
          elif opcion5 == 8:
             X = float(input("Introduce el valor de la distancia en X en metros: ") )
             Y = float(input("Introduce el valor de la distancia en Y en metros: ") )
             Y2 = Y*Y
             X2 = X*X
             R = Y2+X2
             print("El valor de la velocidad total es: ",math.sqrt(R))
        if opcion4 == 4:
          print(" ")
          print("""
    Dime, ¿qué valor vamos a hallar?
    
    1) La velocidad en el eje X
    2) La Velocidad inicial en el eje Y
    3) La velocidad final en el eje Y
    4) El tiempo 
    5) Distancia en X
    6) Altura
    """)
          opcion6 = int(input("Elige una opción: ") )
          if opcion6 == 1:
             print(" ")
             X = float(input("Introduce la la distancia en el eje X en metros: ") )
             t = float(input("Introduce el tiempo en segundos: ") )
             print("El valor de la velocidad en el eje X es: ",X/t)
          elif opcion6 == 2:
             print(" ")
             g = 9.81
             VfY = float(input("Introduce la velocidad final en el eje Y en metros: ") )
             t = float(input("Introduce el tiempo en segundos: ") )
             print("El valor de la velocidad inicial en el eje Y es: ",VfY-(g*t))
          elif opcion6 == 3:
             Viy = float(input("Introduce la velocidad inicial en el eje Y en metros sobre segundos: ") )
             t = float(input("Introduce el tiempo en segundos: ") )
             g = 9.81
             print("El valor de la velocidad final en el eje X es: ",Viy+(g*t))
          elif opcion6 == 4:
             ViY = float(input("Introduce la velocidad inicial en el eje Y en metros sobre segundos: ") )
             VfY = float(input("Introduce la velocidad final en el eje Y en metros sobre segundos: ") )
             g = 9.81
             print("El valor del tiempo es: ",(VfY-ViY)/g)
          elif opcion6 == 5:
             Vx = float(input("Introduce la velocidad en el eje x en metros sobre segundos: ") )
             t = float(input("Introduce el tiempo en segundos: ") )
             print("El valor de la distancia en el eje X es: ",Vx*t)
          elif opcion6 == 6:
             Viy = float(input("Introduce la velocidad inicial en el eje Y en metros sobre segundos: ") )
             t = float(input("Introduce el tiempo en segundos: ") )
             g = 9.81
             gm= g/2
             t2 = t*t
             print("El valor de la altura de la cual  se lanzo el objeto es: ",(Viy*t)+(gm*t2))
    elif opcion == 4:
        break
    else:
        print("""Opción invalida
        
        """)
