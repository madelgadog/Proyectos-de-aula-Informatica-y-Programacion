# %% [markdown]
# <a href="https://colab.research.google.com/github/madelgadog/Proyectos-de-aula-Informatica-y-Programacion/blob/main/Calculo_pH1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
print('El siguiente codigo sirve para poder hallar el pH de una solución a temperatura ambiente en base \nlos datos que usted proporcione para ello se tiene que tener en cuenta 4 parámetros diferentes,\npara el primer parámetro de la solución que se quiera tener debemos saber si es básico o si \nes acida, indique con 1 si la solución es acida y si no indique con 0 que la solución es básica \nAcido = 1 \nBasica = 0')
m=float(input(''))
if m==1:
           print('Ahora que sabemos que su solución es acida, debemos tener en cuenta si es monoprotica,\npoliprótica o si disponemos de una solución buffer, para ello se debe escoger una de estas \ntres opciones y del mismo modo que en el principio se debe escoger en base de la siguiente forma: \nMonoprotica = 1 \nPoliprótico = 2 \nBuffer = 3') 
           b=float(input(''))
           if b==1:
                   print('Su acido es fuerte o débil \nFuerte = 1 \nDébil = 2')
                   b1=float(input(''))
                   if b1==1:
                            print('¿Cuál es el peso molecular de su acido en g/mol?')
                            b11=float(input(''))
                            print('¿Cuál es el volumen en el que desea hacer la solución en Litros?')
                            b12=float(input(''))
                            print('¿Cuántos gramos (g) del ácido desea agregar a ese volumen (L)?')
                            b13=float(input(''))
                            M1=b11/b13
                            M2= M1/b12
                            pH1=-math.log10(M2)
                            print('El pH de su solución acida fuerte es de ',pH1,'')
                   if b1==2:
                            print('¿Cuál es el ka de su acido débil (Nota; El indicador de 10 elevado a se puede usar con la letra e)')
                            b120=float(input(''))   
                            print('¿Cuál es el peso molecular de su acido en g/mol?')
                            b121=float(input(''))
                            print('¿Cuál es el volumen en el que desea hacer la solución en Litros?')
                            b122=float(input(''))
                            print('¿Cuántos gramos (g) del ácido desea agregar a ese volumen (L)?')
                            b123=float(input(''))
                            M121=b123/b121
                            M122= M121/b122
                            M123= ((-b120)+(math.sqrt((b120**2)+(4*b120*M122))))/2
                            pH2=-math.log10(M123)
                            print('El pH de su solución acida débil es de ',pH2,'')
          #poliprotico
           if b==2:
                   print('Sabiendo que su acido es poliprótico, se debe tener en cuenta que cada acido tiene entre 2 a 3 Ka \ndiferentes, por lo que se tiene que tener en cuenta, para ello se debe saber lo siguiente \n¿Su acido tiene 2 o 3 Ka?')
                   b2=float(input(''))
                   if b2==2:
                            print('Agregue las 2 Ka de su acido (Nota; el exponente 10 elevado a se puede usar con la letra e)')
                            b21=float(input(''))
                            b22=float(input(''))
                            print('¿Cuál es el peso molecular de su acido en g/mol?')
                            b23=float(input(''))
                            print('¿Cuál es el volumen en el que desea hacer la solución en Litros?')
                            b24=float(input(''))
                            print('¿Cuántos gramos (g) del ácido desea agregar a ese volumen (L)?')
                            b25=float(input(''))
                            #moles
                            M211=b25/b23
                            #molaridad
                            M212= M211/b24
                            #iones hidronio 1
                            M213= ((-b21)+(math.sqrt((b21**2)+(4*b21*M212))))/2
                            #iones hidronio 2
                            M214= ((-b22)+(math.sqrt((b22**2)+(4*b22*M213))))/2
                            #suma de iones
                            M215=M213+M214
                            #pH
                            pH3=-math.log10(M215)
                            print('El pH de su solución acida poliprotico es de ',pH3,'')
                   if b2==3:
                            print('Agregue las 3 Ka de su acido (Nota; el exponente 10 elevado a se puede usar con la letra e)')
                            b221=float(input(''))
                            b222=float(input(''))
                            b223=float(input(''))
                            print('¿Cuál es el peso molecular de su acido en g/mol?')
                            b224=float(input(''))
                            print('¿Cuál es el volumen en el que desea hacer la solución en Litros?')
                            b225=float(input(''))
                            print('¿Cuántos gramos (g) del ácido desea agregar a ese volumen (L)?')
                            b226=float(input(''))
                            #moles
                            M221=b226/b224
                            #molaridad
                            M222= M221/b225
                            #iones hidronio 1
                            M223= ((-b221)+(math.sqrt((b221**2)+(4*b221*M222))))/2
                            #iones hidronio 2
                            M224= ((-b222)+(math.sqrt((b222**2)+(4*b222*M223))))/2
                            #iones hidronio 3
                            M225= ((-b223)+(math.sqrt((b223**2)+(4*b223*M224))))/2
                            #suma de iones
                            M226=M223+M224+M225
                            #pH
                            pH4=-math.log10(M226)
                            print('El pH de su solución acida poliprotico es de ',pH4,'')
          #buffer acido
           if b==3:
                  print('Usted desea preparar una solución buffer de pH conocido usando una acido y su base conjugada, \npara ello se decidió usar la ecuación de Henderson-Hasselbach, donde debe agregar pka, \nconcentración final de la solución buffer y masa molecular del ácido y su base conjugada, con \nestos se podrá calcular la cantidad de gramos de ácido y de base conjugada necesarios para \nobtener este pH requerido \n¿Cuál es el pH final de su solución buffer?')
                  b3=float(input(''))
                  print('¿Cuál es el pKa del ácido?')
                  b31=float(input(''))
                  print('¿Cuál es la concentración a la que desea preparar la buffer en M?')
                  b32=float(input(''))
                  print('¿Cuál sera el volumen de su solución buffer en Litros?')
                  b321=float(input(''))
                  print('¿Cuál es la masa molecular de su ácido en g/mol?')
                  b33=float(input(''))
                  print('¿Cuál es la masa molecular de su base conjugada en g/mol?')
                  b34=float(input(''))
                  p=b3-b31
                  p1=10**(p)
                  HA1=(b32*b321)/(1+p1)
                  A1=(b32*b321)-HA1
                  gr_ac=HA1*b33
                  gr_bc=A1*b34
                  print('Para obtener un pH de',b3,'se necesitan \n',gr_ac,' gramos de acido y \n',gr_bc,' gramos de base conjugada')
if m==0:
        print('Ahora que sabemos que su solución es básica o alcalina, debemos tener en cuenta si es una base fuerte,\ndébil o si disponemos de una solución buffer, para ello se debe escoger una de estas \ntres opciones y del mismo modo que en el principio se debe escoger en base de la siguiente forma: \nBase fuerte (ej:NaOH) = 1 \nBase débil (ej:NH3) = 2 \nBuffer = 3') 
        c=float(input(''))
        if c==1:
                print('¿Su base tiene mas de un grupo (OH)? \nPor ejemplo una base fuerte con mas de un grupo (OH) seria el Ca(OH)2 \nIndique cuantos grupos (OH) tiene su base fuerte')
                c10=float(input(''))
                print('¿Cuál es el peso molecular de su base en g/mol?')
                c11=float(input(''))
                print('¿Cuál es el volumen en el que desea hacer la solución en Litros?')
                c12=float(input(''))
                print('¿Cuántos gramos (g) de la base que desea agregar a ese volumen (L)?')
                c13=float(input(''))
                #mol
                Mc1=c11/c13
                #molaridad
                Mc2= Mc1/c12
                #M de los OH
                Mc3= c10*Mc2
                pH4=14+math.log10(Mc3)
                print('El pH de su solución básica fuerte es de ',pH4,'')
        #débil
        if c==2:
                print('Si es debil ingrese el Ka de la base y se reformulara el Kb segun la formula Kb*Ka=Kw \n¿Cuál es el ka de su base débil (Nota; El indicador de 10 elevado a se puede usar con la letra e)')
                c120=float(input(''))   
                print('¿Cuál es el peso molecular de su base en g/mol?')
                c121=float(input(''))
                print('¿Cuál es el volumen en el que desea hacer la solución en Litros?')
                c122=float(input(''))
                print('¿Cuántos gramos (g) de la base que desea agregar a ese volumen (L)?')
                c123=float(input(''))
                Kb1=(1e-14)/(c120)
                Mc121=c123/c121
                Mc122= Mc121/c122
                Mc123= ((-Kb1)+(math.sqrt((Kb1**2)+(4*Kb1*Mc122))))/2
                pH5=14+math.log10(Mc123)
                print('El pH de su solución básica débil es de ',pH5,'')
        #buffer base
        if c==3:
                  print('Usted desea preparar una solución buffer de pH conocido usando una base y su ácido conjugado, \npara ello se decidió usar la ecuación de Henderson-Hasselbach, donde debe agregar pka, \nconcentración final de la solución buffer y masa molecular de la base y su ácido conjugado, con \nestos se podrá calcular la cantidad de gramos de base y de ácido conjugado necesarios para \nobtener este pH requerido \n¿Cuál es el pH final de su solución buffer?')
                  c3=float(input(''))
                  print('¿Cuál es el pKa de la base?')
                  c31=float(input(''))
                  print('¿Cuál es la concentración a la que desea preparar la buffer en M?')
                  c32=float(input(''))
                  print('¿Cuál sera el volumen de su solución buffer en Litros?')
                  c321=float(input(''))
                  print('¿Cuál es la masa molecular de su base en g/mol?')
                  c33=float(input(''))
                  print('¿Cuál es la masa molecular de su ácido conjugado en g/mol?')
                  c34=float(input(''))
                  p=c3-c31
                  pc1=10**(p)
                  HAc1=(c32*c321)/(1+pc1)
                  Ac1=(c32*c321)-HAc1
                  gr_b=HAc1*c33
                  gr_ac=Ac1*c34
                  print('Para obtener un pH de',c3,'se necesitan \n',gr_b,' gramos de base y \n',gr_ac,' gramos de ácido conjugado')
# Out:
# El siguiente codigo sirve para poder hallar el pH de una solución a temperatura ambiente en base
# los datos que usted proporcione para ello se tiene que tener en cuenta 4 parámetros diferentes,
# para el primer parámetro de la solución que se quiera tener debemos saber si es básico o si
# es acida, indique con 1 si la solución es acida y si no indique con 0 que la solución es básica
# Acido = 1
# Basica = 0
# 0
# Ahora que sabemos que su solución es básica o alcalina, debemos tener en cuenta si es una base fuerte,
# débil o si disponemos de una solución buffer, para ello se debe escoger una de estas
# tres opciones y del mismo modo que en el principio se debe escoger en base de la siguiente forma:
# Base fuerte (ej:NaOH) = 1
# Base débil (ej:NH3) = 2
# Buffer = 3
# 3
# Usted desea preparar una solución buffer de pH conocido usando una base y su ácido conjugado,
# para ello se decidió usar la ecuación de Henderson-Hasselbach, donde debe agregar pka,
# ...
